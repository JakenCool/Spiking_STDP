# %%
from brian2 import *
import matplotlib.pyplot as plt
import numpy as np

# %%
rpost1 = 30*Hz
rpost2 = 10*Hz
rpre = 10*Hz
N = 5000
T=3*second

rpost = TimedArray([rpost1,rpost2],dt=T/2)

post = PoissonGroup(N, rates='rpost(t)')
pre  = PoissonGroup(N, rates=rpre)

t_forw = 15*ms
t_back = 20*ms
t_r = 2000*ms
A_forw = 7e-3
A_back = A_forw * t_forw/t_back

S = Synapses(pre, post,
         '''
         w : 1
         do_j1/dt  = -o_j1/t_forw   : 1 (event-driven)
         do_i1/dt  = -o_i1/t_back  : 1 (event-driven)
         dr_i1/dt  = -r_i1/t_r     : 1 (event-driven)
         do_j/dt = (o_j1 - o_j)/t_forw : 1 (event-driven) 
         do_i/dt = (o_i1 - o_i)/t_back : 1 (event-driven) 
         dr_i/dt = (r_i1 - r_i)/t_r    : 1 (event-driven)
         ''',
         on_pre='''
                w = w + o_i * A_back * r_i
                o_j1+= 1
                ''',
         on_post='''
                w = w - o_j * A_forw * r_i
                o_i1+=1
                r_i1+=1
                ''',
         )
S.connect(j='i')
w_ori = .5
S.w = w_ori

w_mon = StateMonitor(S, 'w',record=range(N))
post_mon = SpikeMonitor(post)
pre_mon = SpikeMonitor(pre)

run(T)

# %%
plt.plot(w_mon.t/second,mean(w_mon.w.T,1))
plt.xlabel('time (s)')
plt.ylabel('weight (a.u.)')
plt.title(r'$r_{pre}=%dHz$, $r_{post}=%dHz->%dHz$'%(rpre,rpost1,rpost2))
plt.show()

# %%
rpost1 = 30*Hz
rpost2 = 20*Hz
rpre = 10*Hz
N = 5000
T=3*second

rpost = TimedArray([rpost1,rpost2],dt=T/2)

post = PoissonGroup(N, rates='rpost(t)')
pre  = PoissonGroup(N, rates=rpre)

t_forw = 15*ms
t_back = 20*ms
t_r = 2000*ms
A_forw = 7e-3
A_back = A_forw * t_forw/t_back

S = Synapses(pre, post,
         '''
         w : 1
         do_j1/dt  = -o_j1/t_forw   : 1 (event-driven)
         do_i1/dt  = -o_i1/t_back  : 1 (event-driven)
         dr_i1/dt  = -r_i1/t_r     : 1 (event-driven)
         do_j/dt = (o_j1 - o_j)/t_forw : 1 (event-driven) 
         do_i/dt = (o_i1 - o_i)/t_back : 1 (event-driven) 
         dr_i/dt = (r_i1 - r_i)/t_r    : 1 (event-driven)
         ''',
         on_pre='''
                w = w + o_i * A_back * r_i
                o_j1+= 1
                ''',
         on_post='''
                w = w - o_j * A_forw * r_i
                o_i1+=1
                r_i1+=1
                ''',
         )
S.connect(j='i')
w_ori = .5
S.w = w_ori

w_mon = StateMonitor(S, 'w',record=range(N))
post_mon = SpikeMonitor(post)
pre_mon = SpikeMonitor(pre)

run(T)

# %%
plt.plot(w_mon.t/second,mean(w_mon.w.T,1))
plt.xlabel('time (s)')
plt.ylabel('weight (a.u.)')
plt.title(r'$r_{pre}=%dHz$, $r_{post}=%dHz->%dHz$'%(rpre,rpost1,rpost2))
plt.show()

# %%
start_scope()
rpost1 = 40*Hz
rpost2 = 20*Hz
rpre = 10*Hz
N = 5000
T=3*second

rpost = TimedArray([rpost1,rpost2],dt=T/2)

post = PoissonGroup(N, rates='rpost(t)')
pre  = PoissonGroup(N, rates=rpre)

t_forw = 15*ms
t_back = 20*ms
t_r = 2000*ms
A_forw = 7e-3
A_back = A_forw * t_forw/t_back

S = Synapses(pre, post,
         '''
         w : 1
         do_j1/dt  = -o_j1/t_forw   : 1 (event-driven)
         do_i1/dt  = -o_i1/t_back  : 1 (event-driven)
         dr_i1/dt  = -r_i1/t_r     : 1 (event-driven)
         do_j/dt = (o_j1 - o_j)/t_forw : 1 (event-driven) 
         do_i/dt = (o_i1 - o_i)/t_back : 1 (event-driven) 
         dr_i/dt = (r_i1 - r_i)/t_r    : 1 (event-driven)
         ''',
         on_pre='''
                w = w + o_i * A_back * r_i
                o_j1+= 1
                ''',
         on_post='''
                w = w - o_j * A_forw * r_i
                o_i1+=1
                r_i1+=1
                ''',
         )
S.connect(j='i')
w_ori = .5
S.w = w_ori

w_mon = StateMonitor(S, 'w',record=range(N))
post_mon = SpikeMonitor(post)
pre_mon = SpikeMonitor(pre)

run(T)
# Out:
# _cython_magic_a82b666a5f9cc0cef3d0395119d3e600.cpp
# c:\users\golde\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   正在创建库 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_a82b666a5f9cc0cef3d0395119d3e600.cp36-win_amd64.lib 和对象 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_a82b666a5f9cc0cef3d0395119d3e600.cp36-win_amd64.exp
# 正在生成代码
# 已完成代码的生成
# _cython_magic_4fb4ff8bd837795751796d5cf30b7d5b.cpp
# c:\users\golde\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   正在创建库 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_4fb4ff8bd837795751796d5cf30b7d5b.cp36-win_amd64.lib 和对象 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_4fb4ff8bd837795751796d5cf30b7d5b.cp36-win_amd64.exp
# 正在生成代码
# 已完成代码的生成
# _cython_magic_932b25651d0ee0e12341a8d52aac7f3f.cpp
# c:\users\golde\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   正在创建库 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_932b25651d0ee0e12341a8d52aac7f3f.cp36-win_amd64.lib 和对象 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_932b25651d0ee0e12341a8d52aac7f3f.cp36-win_amd64.exp
# 正在生成代码
# 已完成代码的生成
# _cython_magic_59a33b1ebf4d6d209a1c3413fb4c7713.cpp
# c:\users\golde\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   正在创建库 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_59a33b1ebf4d6d209a1c3413fb4c7713.cp36-win_amd64.lib 和对象 C:\Users\golde\.cython\brian_extensions\Users\golde\.cython\brian_extensions\_cython_magic_59a33b1ebf4d6d209a1c3413fb4c7713.cp36-win_amd64.exp
# 正在生成代码
# 已完成代码的生成
# cl: 命令行 warning D9025 :正在重写“/W3”(用“/w”)
# cl: 命令行 warning D9025 :正在重写“/W3”(用“/w”)
# cl: 命令行 warning D9025 :正在重写“/W3”(用“/w”)
# cl: 命令行 warning D9025 :正在重写“/W3”(用“/w”)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-48e1c6c5553c> in <module>()
#      45 pre_mon = SpikeMonitor(pre)
#      46
# ---> 47 run(T)
#
# ~\Anaconda3\lib\site-packages\brian2\units\fundamentalunits.py in new_f(*args, **kwds)
#    2373                                                      get_dimensions(newkeyset[k]))
#    2374
# -> 2375             result = f(*args, **kwds)
#    2376             if 'result' in au:
#    2377                 if au['result'] == bool:
#
# ~\Anaconda3\lib\site-packages\brian2\core\magic.py in run(duration, report, report_period, namespace, profile, level)
#     369     '''
#     370     return magic_network.run(duration, report=report, report_period=report_period,
# --> 371                              namespace=namespace, profile=profile, level=2+level)
#     372 run.__module__ = __name__
#     373
#
# ~\Anaconda3\lib\site-packages\brian2\core\magic.py in run(self, duration, report, report_period, namespace, profile, level)
#     229         self._update_magic_objects(level=level+1)
#     230         Network.run(self, duration, report=report, report_period=report_period,
# --> 231                     namespace=namespace, profile=profile, level=level+1)
#     232
#     233     def store(self, name='default', filename=None, level=0):
#
# ~\Anaconda3\lib\site-packages\brian2\core\base.py in device_override_decorated_function(*args, **kwds)
#     276                 return getattr(curdev, name)(*args, **kwds)
#     277             else:
# --> 278                 return func(*args, **kwds)
#     279
#     280         device_override_decorated_function.__doc__ = func.__doc__
#
# ~\Anaconda3\lib\site-packages\brian2\units\fundamentalunits.py in new_f(*args, **kwds)
#    2373                                                      get_dimensions(newkeyset[k]))
#    2374
# -> 2375             result = f(*args, **kwds)
#    2376             if 'result' in au:
#    2377                 if au['result'] == bool:
#
# ~\Anaconda3\lib\site-packages\brian2\core\network.py in run(self, duration, report, report_period, namespace, profile, level)
#     949             namespace = get_local_namespace(level=level+3)
#     950
# --> 951         self.before_run(namespace)
#     952
#     953         if len(self.objects)==0:
#
# ~\Anaconda3\lib\site-packages\brian2\core\base.py in device_override_decorated_function(*args, **kwds)
#     276                 return getattr(curdev, name)(*args, **kwds)
#     277             else:
# --> 278                 return func(*args, **kwds)
#     279
#     280         device_override_decorated_function.__doc__ = func.__doc__
#
# ~\Anaconda3\lib\site-packages\brian2\core\network.py in before_run(self, run_namespace)
#     839             if obj.active:
#     840                 try:
# --> 841                     obj.before_run(run_namespace)
#     842                 except Exception as ex:
#     843                     raise brian_object_exception("An error occurred when preparing an object.", obj, ex)
#
# ~\Anaconda3\lib\site-packages\brian2\groups\group.py in before_run(self, run_namespace)
#    1113                                                  template_kwds=self.template_kwds,
#    1114                                                  override_conditional_write=self.override_conditional_write,
# -> 1115                                                  codeobj_class=self.codeobj_class
#    1116                                                  )
#    1117             self.code_objects[:] = [weakref.proxy(self.codeobj)]
#
# ~\Anaconda3\lib\site-packages\brian2\codegen\codeobject.py in create_runner_codeobj(group, code, template_name, run_namespace, user_code, variable_indices, name, check_units, needed_variables, additional_variables, template_kwds, override_conditional_write, codeobj_class)
#     308                               template_kwds=template_kwds,
#     309                               codeobj_class=codeobj_class,
# --> 310                               override_conditional_write=override_conditional_write,
#     311                               )
#
# ~\Anaconda3\lib\site-packages\brian2\devices\device.py in code_object(self, owner, name, abstract_code, variables, template_name, variable_indices, codeobj_class, template_kwds, override_conditional_write)
#     334                                 template_source=template.template_source,
#     335                                 name=name)
# --> 336         codeobj.compile()
#     337         return codeobj
#     338
#
# ~\Anaconda3\lib\site-packages\brian2\codegen\runtime\cython_rt\cython_rt.py in compile(self)
#     128             library_dirs=self.library_dirs,
#     129             compiler=self.compiler,
# --> 130             owner_name=self.owner.name+'_'+self.template_name,
#     131             )
#     132
#
# ~\Anaconda3\lib\site-packages\brian2\codegen\runtime\cython_rt\extension_manager.py in create_extension(self, code, force, name, define_macros, include_dirs, library_dirs, runtime_library_dirs, extra_compile_args, extra_link_args, libraries, compiler, owner_name)
#     132                                          runtime_library_dirs=runtime_library_dirs,
#     133                                          compiler=compiler,
# --> 134                                          key=key)
#     135                 # Unlock
#     136                 if msvcrt:
#
# ~\Anaconda3\lib\site-packages\brian2\codegen\runtime\cython_rt\extension_manager.py in _load_module(self, module_path, define_macros, include_dirs, library_dirs, extra_compile_args, extra_link_args, libraries, code, lib_dir, module_name, runtime_library_dirs, compiler, key)
#     261                     build_extension.build_temp = os.path.dirname(pyx_file)
#     262                     build_extension.build_lib = lib_dir
# --> 263                     build_extension.run()
#     264                     if prefs['codegen.runtime.cython.delete_source_files']:
#     265                         # we can delete the source files to save disk space
#
# ~\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     337
#     338         # Now actually compile and link everything.
# --> 339         self.build_extensions()
#     340
#     341     def check_extensions_list(self, extensions):
#
# ~\Anaconda3\lib\distutils\command\build_ext.py in build_extensions(self)
#     446             self._build_extensions_parallel()
#     447         else:
# --> 448             self._build_extensions_serial()
#     449
#     450     def _build_extensions_parallel(self):
#
# ~\Anaconda3\lib\distutils\command\build_ext.py in _build_extensions_serial(self)
#     471         for ext in self.extensions:
#     472             with self._filter_build_errors(ext):
# --> 473                 self.build_extension(ext)
#     474
#     475     @contextlib.contextmanager
#
# ~\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     531                                          debug=self.debug,
#     532                                          extra_postargs=extra_args,
# --> 533                                          depends=ext.depends)
#     534
#     535         # XXX outdated variable, kept here in case third-part code
#
# ~\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     343
#     344         if not self.initialized:
# --> 345             self.initialize()
#     346         compile_info = self._setup_compile(output_dir, macros, include_dirs,
#     347                                            sources, depends, extra_postargs)
#
# ~\Anaconda3\lib\distutils\_msvccompiler.py in initialize(self, plat_name)
#     236         plat_spec = PLAT_TO_VCVARS[plat_name]
#     237
# --> 238         vc_env = _get_vc_env(plat_spec)
#     239         if not vc_env:
#     240             raise DistutilsPlatformError("Unable to find a compatible "
#
# ~\Anaconda3\lib\site-packages\setuptools\msvc.py in msvc14_get_vc_env(plat_spec)
#     176     # Try to get environment from vcvarsall.bat (Classical way)
#     177     try:
# --> 178         return get_unpatched(msvc14_get_vc_env)(plat_spec)
#     179     except distutils.errors.DistutilsPlatformError:
#     180         # Pass error Vcvarsall.bat is missing
#
# ~\Anaconda3\lib\distutils\_msvccompiler.py in _get_vc_env(plat_spec)
#     137         out = subprocess.check_output(
#     138             'cmd /u /c "{}" {} && set'.format(vcvarsall, plat_spec),
# --> 139             stderr=subprocess.STDOUT,
#     140         ).decode('utf-16le', errors='replace')
#     141     except subprocess.CalledProcessError as exc:
#
# ~\Anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# ~\Anaconda3\lib\subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# ~\Anaconda3\lib\subprocess.py in communicate(self, input, timeout)
#     828                 self._stdin_write(input)
#     829             elif self.stdout:
# --> 830                 stdout = self.stdout.read()
#     831                 self.stdout.close()
#     832             elif self.stderr:
#
# KeyboardInterrupt:

# %%
plt.plot(w_mon.t/second,mean(w_mon.w.T,1))
plt.xlabel('time (s)')
plt.ylabel('weight (a.u.)')
plt.title(r'$r_{pre}=%dHz$, $r_{post}=%dHz->%dHz$'%(rpre,rpost1,rpost2))
plt.show()

# %%
start_scope()
rpost1 = 60*Hz
rpost2 = 40*Hz
rpre = 10*Hz
N = 5000
T=3*second

rpost = TimedArray([rpost1,rpost2],dt=T/2)

post = PoissonGroup(N, rates='rpost(t)')
pre  = PoissonGroup(N, rates=rpre)

t_forw = 15*ms
t_back = 20*ms
t_r = 2000*ms
A_forw = 7e-3
A_back = A_forw * t_forw/t_back

S = Synapses(pre, post,
         '''
         w : 1
         do_j1/dt  = -o_j1/t_forw   : 1 (event-driven)
         do_i1/dt  = -o_i1/t_back  : 1 (event-driven)
         dr_i1/dt  = -r_i1/t_r     : 1 (event-driven)
         do_j/dt = (o_j1 - o_j)/t_forw : 1 (event-driven) 
         do_i/dt = (o_i1 - o_i)/t_back : 1 (event-driven) 
         dr_i/dt = (r_i1 - r_i)/t_r    : 1 (event-driven)
         ''',
         on_pre='''
                w = w + o_i * A_back * r_i
                o_j1+= 1
                ''',
         on_post='''
                w = w - o_j * A_forw * r_i
                o_i1+=1
                r_i1+=1
                ''',
         )
S.connect(j='i')
w_ori = .5
S.w = w_ori

w_mon = StateMonitor(S, 'w',record=range(N))
post_mon = SpikeMonitor(post)
pre_mon = SpikeMonitor(pre)

run(T)

# %%
plt.plot(w_mon.t/second,mean(w_mon.w.T,1))
plt.xlabel('time (s)')
plt.ylabel('weight (a.u.)')
plt.title(r'$r_{pre}=%dHz$, $r_{post}=%dHz->%dHz$'%(rpre,rpost1,rpost2))
plt.show()
